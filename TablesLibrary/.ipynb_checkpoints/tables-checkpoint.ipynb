# %%
# Create Table
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Create Table Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    Log  ${table}[0]

*** Tasks ***
Create Table keyword Example
    Create Table Keyword in Tables Library

# %%
# Add Table Column
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Add Table Column Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Add table column  ${table}  name=Address  values=Testing
    Log  ${table}[0]

*** Tasks ***
Add Table Column keyword Example
    Add Table Column Keyword in Tables Library

# %%
# Add Table Row
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Add Table Row Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Add table Row  ${table}  Unknown
    Log  ${table}[-1]

*** Tasks ***
Add Table Row keyword Example
    Add Table Row Keyword in Tables Library

# %%
# Clear Table
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Clear Table Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Clear table  ${table}
    Log  ${table}

*** Tasks ***
Clear Table keyword Example
    Clear Table Keyword in Tables Library

# %%
# Copy Table
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Copy Table Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    ${copy_table}  Copy table  ${table}
    Log  ${table}
    Log  ${copy_table}

*** Tasks ***
Copy Table keyword Example
    Copy Table Keyword in Tables Library

# %%
# Export Table
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Export Table Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Export table  ${table}

*** Tasks ***
Export Table keyword Example
    Export Table Keyword in Tables Library

# %%
# Export Table
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Export Table Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  
    ${table_data_age}   Create list  18   20   22   23    16    12      
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  
    ${table_data_score}  Create list  None  None  None  None  None  None  
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Filter empty rows  ${table}
    Write table to csv  ${table}  output.csv

*** Tasks ***
Export Table keyword Example
    Export Table Keyword in Tables Library

# %%
# Filter Table By Column
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Filter Table By Column Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Filter Table By Column  ${table}  gender  !=  Male
    Write table to csv  ${table}  filter.csv

*** Tasks ***
Filter Table By Column keyword Example
    Filter Table By Column Keyword in Tables Library

# %%
# Find Table Rows
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Find Table Rows Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Find Table Rows  ${table}  gender  !=  Male
    Write table to csv  ${table}  rows.csv

*** Tasks ***
Find Table Rows keyword Example
    Find Table Rows Keyword in Tables Library

# %%
# Get Table Cells
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Get Table Cell Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    ${value1}=  Get Table Cell  ${table}  0  0  
    Log  ${value1}
    
    ${value2}=  Get Table Cell  ${table}  -1  0  
    Log  ${value2}
    
    ${value3}=  Get Table Cell  ${table}  2  name  
    Log  ${value3}
    
    

*** Tasks ***
Get Table Cell keyword Example
    Get Table Cell Keyword in Tables Library

# %%
# Get Table Column
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Get Table Column Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    ${values}=  Get table column  ${table}  gender
    
    FOR  ${val}  IN  @{values}
        Log  ${val}
    END
    
    
*** Tasks ***
Get Table Column keyword Example
    Get Table Column Keyword in Tables Library

# %%
# Get Table Dimensions
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Get Table Dimensions Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    ${rows}  ${columns}  Get table dimensions  ${table}
    Log  Table has ${rows} rows and ${columns} columns.
    
    
*** Tasks ***
Get Table Dimensions keyword Example
    Get Table Dimensions Keyword in Tables Library

# %%
# Get Table Row
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Get Table Row Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    ${row_values}  Get table row  ${table}  -1  as_list=${TRUE}
    Log  ${row_values}
    
    
*** Tasks ***
Get Table Row keyword Example
    Get Table Row Keyword in Tables Library

# %%
# Get Table Slice
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Get Table Slice Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    ${slice}  Get table slice  ${table}  start=3  end=7
    Log  ${slice}
    
    
*** Tasks ***
Get Table Slice keyword Example
    Get Table Slice Keyword in Tables Library

# %%
# Group Table By Column
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Group Table By Column Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    ${groups}=  Group table by column  ${table}  gender
    FOR  ${group}  IN  @{groups}
        Log  ${group}
    END
    
    
*** Tasks ***
Group Table By Column keyword Example
    Group Table By Column Keyword in Tables Library

# %%
# Pop Table Columns
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Pop Table Column Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    ${table_dummy_col}   Create list  1  1  1  1  1  1  1
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    ...    dummy_col=${table_dummy_col}
    
    ${table}=  Create table  ${table_data}
    
    Log  Before:${table}
    Pop table column  ${table}  dummy_col
    Log  After:${table}
    
    
*** Tasks ***
Pop Table Column keyword Example
    Pop Table Column Keyword in Tables Library

# %%
# Sort Table By Column
*** Settings ***
Library  Autosphere.Tables
Library  Collections

*** Keywords ***
Sort Table By Column Keyword in Tables Library
    ${table_data_name}  Create list  joe  doe  sam  john  root  smith  waugh
    ${table_data_age}   Create list  18   20   22   23    16    12      30
    ${table_data_gender}  Create list  Male  Female  Male  Male  Female  Male  Male
    ${table_data_score}  Create list  90  100  68  54  30  15  45
    
    ${table_data}  Create dictionary  
    ...    name=${table_data_name}
    ...    age=${table_data_age}
    ...    gender=${table_data_gender}
    ...    score=${table_data_score}
    
    ${table}=  Create table  ${table_data}
    
    Log  Before:${table}
    Sort table by column  ${table}  score  ascending=${True}
    Write table to csv  ${table}  sort.csv
    Log  After:${table}
    
    
*** Tasks ***
Sort Table By Column keyword Example
    Sort Table By Column Keyword in Tables Library
